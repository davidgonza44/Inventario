# %% [markdown]
# <a href="https://colab.research.google.com/github/davidgonza44/Inventario/blob/main/R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![R.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # ¿Qué es R?
# R es un lenguaje de programación popular utilizado para cálculos estadísticos y presentaciones gráficas.
#
# Su uso más común es analizar y visualizar datos.
#
# # ¿Por qué utilizar R?
# Es un gran recurso para el análisis de datos, visualización de datos, ciencia de datos y aprendizaje automático.
# Proporciona muchas técnicas estadísticas (como pruebas estadísticas, clasificación, agrupamiento y reducción de datos).
# Es fácil dibujar gráficos en R, como gráficos circulares, histogramas, diagramas de caja, diagramas de dispersión, etc.++
# Funciona en diferentes plataformas (Windows, Mac, Linux)
# Es de código abierto y gratuito.
# Tiene un gran apoyo comunitario.
# Tiene muchos paquetes (bibliotecas de funciones) que se pueden utilizar para resolver diferentes problemas.
#
# # Cómo instalar R
# Para instalar R, vaya a https://cloud.r-project.org/ y descargue la última versión de R para Windows, Mac o Linux.
#
# Cuando haya descargado e instalado R, podrá ejecutarlo en su computadora.
#
# La siguiente captura de pantalla muestra cómo podría verse cuando ejecuta R en una PC con Windows:

# %% [markdown]
# ![R_img.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Sintaxis
# Para generar texto en R, utilice comillas simples o dobles:
#
# Ejemplo
#
# ```
# "Hola Mundo"
# ```
# Para generar números, simplemente escriba el número (sin comillas):
#
# Ejemplo
# 5
# 10
# 25
#
# # Imprimir
# A diferencia de muchos otros lenguajes de programación, puedes generar código en R sin utilizar una función de impresión:
#
# # Ejemplo
# ```
# "Hello World!"
# ```
# Sin embargo, R tiene una print()función disponible si quieres usarla. Esto puede resultar útil si estás familiarizado con otros lenguajes de programación, como Python , que suele utilizar la print()función para generar código.
#
# # Ejemplo
# ```
# print("Hello World!")
# ```
# Y hay ocasiones en las que debes usar la print()función para generar código, por ejemplo, cuando trabajas con for bucles (sobre lo que aprenderás más en un capítulo posterior):
#
# # Ejemplo
# ```
# for (x in 1:10) {
#   print(x)
# }
# ```

# %% [markdown]
# # Comentarios
# Los comentarios se pueden utilizar para explicar el código R y hacerlo más legible. También se pueden utilizar para evitar la ejecución al probar código alternativo.
#
# Los comentarios comienzan con #. Al ejecutar código, R ignorará cualquier cosa que comience con #.
#
# Este ejemplo utiliza un comentario antes de una línea de código:
#
# # Ejemplo
# ```
# # This is a comment
# "Hello World!"
# ```
# Este ejemplo utiliza un comentario al final de una línea de código:
#
# # Ejemplo
# ```
# "Hello World!" # This is a comment
# ```
# Los comentarios no tienen que ser texto para explicar el código, también se pueden usar para evitar que R ejecute el código:
#
# # Ejemplo
# ```
# # "Good morning!"
# "Good night!"
# ```
# # Comentarios multilineales
# A diferencia de otros lenguajes de programación, como Java , en R no existe una sintaxis para los comentarios multilínea. Sin embargo, podemos insertar un #for en cada línea para crear comentarios multilínea:
#
# # Ejemplo
# ```
# # This is a comment
# # written in
# # more than just one line
# "Hello World!"
# ```

# %% [markdown]
# # Creando variables en R
# Las variables son contenedores para almacenar valores de datos.
#
# R no tiene un comando para declarar una variable. Una variable se crea en el momento en que se le asigna un valor por primera vez. Para asignar un valor a una variable, utilice el <- signo . Para generar (o imprimir) el valor de la variable, simplemente escriba el nombre de la variable:
#
# # Ejemplo
# ```
# name <- "John"
# age <- 40
#
# name   # output "John"
# age    # output 40
# ```
# Del ejemplo anterior, ```name``` y ```age`` son variables , mientras que "John"y 40 son valores .
#
# En otros lenguajes de programación, es común utilizar =como operador de asignación. En R, podemos utilizar tanto ```=``` como ```<- ```como operadores de asignación.
#
# Sin embargo, <-se prefiere en la mayoría de los casos porque el =operador puede estar prohibido en algunos contextos en R.
#
# # Variables de impresión/salida
# En comparación con muchos otros lenguajes de programación, en R no es necesario utilizar una función para imprimir o generar variables. Simplemente puede escribir el nombre de la variable:
#
# # Ejemplo
# ```
# name <- "John Doe"
#
# name # auto-print the value of the name variable
# ```
# Sin embargo, R tiene una print()función disponible si quieres usarla. Esto puede ser útil si estás familiarizado con otros lenguajes de programación, como Python , que suelen usar una print()función para generar variables.
#
# # Ejemplo
# ```
# name <- "John Doe"
# print(name) # print the value of the name variable
# ```
# Y hay ocasiones en las que debes usar la print()función para generar código, por ejemplo, cuando trabajas con for bucles (sobre lo que aprenderás más en un capítulo posterior):
#
# # Ejemplo
# ```
# for (x in 1:10) {
#   print(x)
# }
# ```

# %% [markdown]
# # Concatenar elementos
# También puedes concatenar o unir dos o más elementos mediante la paste()función.
#
# Para combinar texto y una variable, R usa la coma ( , ):
#
# # Ejemplo
# ```
# text <- "awesome"
#
# paste("R is", text)
# ```
# También puedes usar ,para agregar una variable a otra variable:
#
# # Ejemplo
# ```
# text1 <- "R is"
# text2 <- "awesome"
#
# paste(text1, text2)
# ```
# Para los números, el +carácter funciona como un operador matemático:
#
# # Ejemplo
# ```
# num1 <- 5
# num2 <- 10
#
# num1 + num2
# ```
# Si intenta combinar una cadena (texto) y un número, R le dará un error:
#
# # Ejemplo
# ```
# num <- 5
# text <- "Some text"
#
# num + text
# Resultado:
#
# Error in num + text : non-numeric argument to binary operator
# ```
#
# # Variables múltiples
# R le permite asignar el mismo valor a múltiples variables en una línea:
#
# # Ejemplo
# ```
# # Assign the same value to multiple variables in one line
# var1 <- var2 <- var3 <- "Orange"
#
# # Print variable values
# var1
# var2
# var3
# ```

# %% [markdown]
# # Nombres de variables
# Una variable puede tener un nombre corto (como x e y) o un nombre más descriptivo (edad, nombre del vehículo, volumen total). Las reglas para las variables R son:
# El nombre de una variable debe comenzar con una letra y puede ser una combinación de letras, dígitos, punto(.)
# y guión bajo(_). Si comienza con punto(.), no puede ir seguido de un dígito.
# Un nombre de variable no puede comenzar con un número o un guión bajo (_)
# Los nombres de las variables distinguen entre mayúsculas y minúsculas (edad, Edad y EDAD son tres variables diferentes)
# Las palabras reservadas no se pueden utilizar como variables (VERDADERO, FALSO, NULO, si...)
# ```
# # Legal variable names:
# myvar <- "John"
# my_var <- "John"
# myVar <- "John"
# MYVAR <- "John"
# myvar2 <- "John"
# .myvar <- "John"
#
# # Illegal variable names:
# 2myvar <- "John"
# my-var <- "John"
# my var <- "John"
# _my_var <- "John"
# my_v@ar <- "John"
# TRUE <- "John"
# ```

# %% [markdown]
# # Tipos de datos
# En programación, el tipo de datos es un concepto importante.
#
# Las variables pueden almacenar datos de diferentes tipos, y diferentes tipos pueden hacer cosas diferentes.
#
# En R, no es necesario declarar las variables con ningún tipo en particular, e incluso pueden cambiar de tipo después de haber sido configuradas:
#
# # Ejemplo
# ```
# my_var <- 30 # my_var is type of numeric
# my_var <- "Sally" # my_var is now of type character (aka string)
# ```
# R tiene una variedad de tipos de datos y clases de objetos. Aprenderá mucho más sobre ellos a medida que continúe conociendo R.
#
# # Tipos de datos básicos
# Los tipos de datos básicos en R se pueden dividir en los siguientes tipos:
#
# *numeric-* (10.5, 55, 787)
#
#
# *integer-* (1L, 55L, 100L, donde la letra "L" declara esto como un entero)
#
# *complex-* (9 + 3i, donde "i" es la parte imaginaria)
#
# *character*(también conocida como cadena) - ("k", "R es emocionante", "FALSO", "11.5")
#
# *logical*(también conocido como booleano) - (VERDADERO o FALSO)
# Podemos utilizar la class()función para comprobar el tipo de datos de una variable:
#
#
# # Ejemplo
# ```
# # numeric
# x <- 10.5
# class(x)
#
# # integer
# x <- 1000L
# class(x)
#
# # complex
# x <- 9i + 3
# class(x)
#
# # character/string
# x <- "R is exciting"
# class(x)
#
# # logical/boolean
# x <- TRUE
# class(x)
# ```

# %% [markdown]
# # Matemáticas simples
# En R, puedes usar operadores para realizar operaciones matemáticas comunes con números.
#
# El +operador se utiliza para sumar dos valores:
#
# # Ejemplo
# ```
# 10 + 5
# -Y para restar se utiliza el operador:
# ```
# # Ejemplo
# ```
# 10 - 5
# ```
#
# # Funciones matemáticas integradas
# R también tiene muchas funciones matemáticas integradas que le permiten realizar tareas matemáticas con números.
#
# Por ejemplo, las funciones min()y max()se pueden utilizar para encontrar el número más bajo o más alto de un conjunto:
#
# # Ejemplo
# ```
# max(5, 10, 15)
#
# min(5, 10, 15)
# ```

# %% [markdown]
# # sqrt()
# La sqrt()función devuelve la raíz cuadrada de un número:
#
# # Ejemplo
# ```
# sqrt(16)
# ```
# # abs()
# La abs()función devuelve el valor absoluto (positivo) de un número:
#
# # Ejemplo
# ```
# abs(-4.7)
# ```
# # ceiling() y floor()
# La ceiling() función redondea un número hacia arriba hasta su entero más cercano, y la floor() función redondea un número hacia abajo hasta su entero más cercano y devuelve el resultado:
#
# # Ejemplo
# ```
# ceiling(1.4)
#
# floor(1.4)
# ```

# %% [markdown]
# # Literales de cadena
# Las cadenas se utilizan para almacenar texto.
#
# Una cadena está rodeada por comillas simples o comillas dobles:
#
# "hello"es lo mismo que 'hello':
#
# # Ejemplo
# ```
# "hello"
# 'hello'
# ```
# # Asignar una cadena a una variable
# La asignación de una cadena a una variable se realiza con la variable seguida del <-operador y la cadena:
#
# # Ejemplo
# ```
# str <- "Hello"
# str # print the value of str
# ```
# # Cadenas multilineales
# Puede asignar una cadena de varias líneas a una variable de la siguiente manera:
#
# # Ejemplo
# ```
# str <- "Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua."
#
# str # print the value of str
# ```
# Sin embargo, tenga en cuenta que R agregará un " \n " al final de cada salto de línea. Esto se denomina carácter de escape y el carácter n indica una nueva línea .
#
# Si desea que los saltos de línea se inserten en la misma posición que en el código, utilice la cat()función:
#
# # Ejemplo
# ```
# str <- "Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua."
#
# cat(str)
# ```

# %% [markdown]
# # Longitud de la cuerda
# Hay muchas funciones de cadena útiles en R.
#
# Por ejemplo, para encontrar el número de caracteres en una cadena, utilice la nchar()función:
#
# # Ejemplo
# ```
# str <- "Hello World!"
#
# nchar(str)
# ```
# # Comprobar una cadena
# Utilice la grepl()función para comprobar si un carácter o una secuencia de caracteres están presentes en una cadena:
#
# # Ejemplo
# ```
# str <- "Hello World!"
#
# grepl("H", str)
# grepl("Hello", str)
# grepl("X", str)
# ```
# # Combinar dos cadenas
# Utilice la paste()función para fusionar/concatenar dos cadenas:
#
# # Ejemplo
# ```
# str1 <- "Hello"
# str2 <- "World"
#
# paste(str1, str2)
# ```

# %% [markdown]
# # Caracteres de escape
# Para insertar caracteres que no son válidos en una cadena, debe utilizar un carácter de escape.
#
# Un carácter de escape es una barra invertida \seguida del carácter que desea insertar.
#
# Un ejemplo de un carácter ilegal es una comilla doble dentro de una cadena que está rodeada por comillas dobles:
#
# # Ejemplo
# ```
# str <- "We are the so-called "Vikings", from the north."
#
# str
# Resultado:
#
# Error: unexpected symbol in "str <- "We are the so-called "Vikings"
# ```
# Para solucionar este problema, utilice el carácter de escape \":
#
# # Ejemplo
# El carácter de escape le permite utilizar comillas dobles cuando normalmente no estaría permitido:
# ```
# str <- "We are the so-called \"Vikings\", from the north."
#
# str
# cat(str)
# ```
# Tenga en cuenta que la impresión automática de la variable str imprimirá la barra invertida en la salida. Puede utilizar la cat()función para imprimirla sin barra invertida.
#
# Otros caracteres de escape en R:
# ```
# Code	Result
# \\	Backslash
# \n	New Line
# \r	Carriage Return
# \t	Tab
# \b	Backspace
# ```

# %% [markdown]
# # La declaración if
# Una "declaración if" se escribe con la if palabra clave y se utiliza para especificar un bloque de código que se ejecutará si se cumple una condición ```TRUE```:
#
# # Ejemplo
# ```
# a <- 33
# b <- 200
#
# if (b > a) {
#   print("b is greater than a")
# }
# ```
# En este ejemplo, utilizamos dos variables, a y b , que se utilizan como parte de la declaración if para comprobar si b es mayor que a . Como a es 33 y b es 200 , sabemos que 200 es mayor que 33, por lo que imprimimos en la pantalla que "b es mayor que a".
#
# R utiliza llaves { } para definir el alcance en el código.

# %% [markdown]
# # Else if
# La else if palabra clave es la forma que tiene R de decir "si las condiciones anteriores no eran verdaderas, entonces pruebe esta condición":
#
# # Ejemplo
# ```
# a <- 33
# b <- 33
#
# if (b > a) {
#   print("b is greater than a")
# } else if (a == b) {
#   print ("a and b are equal")
# }
# ```
# En este ejemplo aes igual a b, por lo que la primera condición no es verdadera, pero la else if condición sí lo es, por lo que imprimimos en pantalla que "a y b son iguales".
#
# Puedes utilizar tantas else if declaraciones como quieras en R.
#
# # If else
# La ```else``` palabra clave captura todo lo que no esté incluido en las condiciones anteriores:
#
# ```
# Ejemplo
# a <- 200
# b <- 33
#
# if (b > a) {
#   print("b is greater than a")
# } else if (a == b) {
#   print("a and b are equal")
# } else {
#   print("a is greater than b")
# }
# ```
# En este ejemplo, a es mayor que b , por lo que la primera condición no es verdadera, tampoco la condición else if es verdadera, por lo que vamos a la condición else e imprimimos en la pantalla que "a es mayor que b".
#
# También puedes utilizar ```else``` sin ```else if```:
#
# # Ejemplo
# ```
# a <- 200
# b <- 33
#
# if (b > a) {
#   print("b is greater than a")
# } else {
#   print("b is not greater than a")
# }
# ```

# %% [markdown]
# # Sentencias If anidadas
# También puedes tener ifdeclaraciones dentro ifde declaraciones, esto se llama declaraciones anidadas . if
#
# # Ejemplo
# ```
# x <- 41
#
# if (x > 10) {
#   print("Above ten")
#   if (x > 20) {
#     print("and also above 20!")
#   } else {
#     print("but not above 20.")
#   }
# } else {
#   print("below 10.")
# }
# ```

# %% [markdown]
# # AND
# El símbolo & (y) es un operador lógico y se utiliza para combinar declaraciones condicionales:
#
# Ejemplo
# Pruebe si a es mayor que b, Y si c es mayor que a:
# ```
# a <- 200
# b <- 33
# c <- 500
#
# if (a > b & c > a) {
#   print("Both conditions are true")
# }
# ```
# # OR
# El | símbolo (o) es un operador lógico y se utiliza para combinar declaraciones condicionales:
#
# # Ejemplo
# Comprueba si a es mayor que b, o si c es mayor que a:
# ```
# a <- 200
# b <- 33
# c <- 500
#
# if (a > b | a > c) {
#   print("At least one of the conditions is true")
# }
# ```

# %% [markdown]
# # Bucles
# Los bucles pueden ejecutar un bloque de código siempre que se alcance una condición especificada.
#
# Los bucles son útiles porque ahorran tiempo, reducen errores y hacen que el código sea más legible.
#
# R tiene dos comandos de bucle:
#
# while bucles
#
# for bucles
#
# # Bucles While de R
# Con el while bucle podemos ejecutar un conjunto de sentencias siempre que una condición sea VERDADERA:
#
# # Ejemplo
# Imprimir i siempre que i sea menor a 6:
# ```
# i <- 1
# while (i < 6) {
#   print(i)
#   i <- i + 1
# }
# ```
# En el ejemplo anterior, el bucle continuará produciendo números del 1 al 5. El bucle se detendrá en 6 porque 6 < 6 es FALSO.
#
# El ```while``` bucle requiere que las variables relevantes estén listas, en este ejemplo necesitamos definir una variable de indexación, i, que establecemos en 1.
#
# # Nota: recuerda incrementar i, de lo contrario el bucle continuará para siempre.
#
# # Break
# Con la ```break``` declaración, podemos detener el bucle incluso si la condición while es VERDADERA:
#
# # Ejemplo
# Salir del bucle si ies igual a 4.
# ```
# i <- 1
# while (i < 6) {
#   print(i)
#   i <- i + 1
#   if (i == 4) {
#     break
#   }
# }
# ```
# El bucle se detendrá en 3 porque hemos elegido finalizar el bucle utilizando la breakdeclaración cuando ies igual a 4 ( i == 4).
#
#
# # Next
# Con la ```next``` declaración, podemos omitir una iteración sin terminar el bucle:
#
# # Ejemplo
# Omitir el valor de 3:
# ```
# i <- 0
# while (i < 6) {
#   i <- i + 1
#   if (i == 3) {
#     next
#   }
#   print(i)
# }
# ```
# Cuando el bucle pasa el valor 3, lo omitirá y continuará el bucle.
#
# ¡Yahtzee!
# # If...Else combinado con un bucle While
# Para demostrar un ejemplo práctico, digamos que jugamos una partida de Yahtzee.
#
# # Ejemplo
# Imprime "¡Yahtzee!" Si el número del dado es 6:
# ```
# dice <- 1
# while (dice <= 6) {
#   if (dice < 6) {
#     print("No Yahtzee")
#   } else {
#     print("Yahtzee!")
#   }
#   dice <- dice + 1
# }
# ```

# %% [markdown]
# # Bucles anidados
# También es posible colocar un bucle dentro de otro bucle. Esto se denomina bucle anidado :
#
# # Ejemplo
# Imprime el adjetivo de cada fruta en una lista:
# ```
# adj <- list("red", "big", "tasty")
#
# fruits <- list("apple", "banana", "cherry")
#   for (x in adj) {
#     for (y in fruits) {
#       print(paste(x, y))
#   }
# }
# ```

# %% [markdown]
# Una función es un bloque de código que solo se ejecuta cuando se lo llama.
#
# Puede pasar datos, conocidos como parámetros, a una función.
#
# Una función puede devolver datos como resultado.
#
# # Creando una función
# Para crear una función, utilice la function()palabra clave:
#
# # Ejemplo
# ```
# my_function <- function() { # create a function with the name my_function
#   print("Hello World!")
# }
# ```
# # Llamar a una función
# Para llamar a una función, utilice el nombre de la función seguido de paréntesis, como ```my_function() ```:
#
# # Ejemplo
# ```
# my_function <- function() {
#   print("Hello World!")
# }
#
# my_function() # call the function named my_function
# ```
# # Argumentos
# La información se puede pasar a funciones como argumentos.
#
# Los argumentos se especifican después del nombre de la función, dentro de los paréntesis. Puedes agregar tantos argumentos como quieras, solo sepáralos con una coma.
#
# El siguiente ejemplo tiene una función con un argumento (fname). Cuando se llama a la función, pasamos un nombre, que se utiliza dentro de la función para imprimir el nombre completo:
#
# # Ejemplo
# ```
# my_function <- function(fname) {
#   paste(fname, "Griffin")
# }
#
# my_function("Peter")
# my_function("Lois")
# my_function("Stewie")
# ```
# # ¿Parámetros o argumentos?
# Los términos "parámetro" y "argumento" se pueden usar para lo mismo: información que se pasa a una función.
#
# Desde la perspectiva de una función:
#
# Un parámetro es la variable que aparece dentro de los paréntesis en la definición de la función.
#
# Un argumento es el valor que se envía a la función cuando se llama.

# %% [markdown]
# # Número de argumentos
# De forma predeterminada, una función debe llamarse con la cantidad correcta de argumentos. Esto significa que si su función espera 2 argumentos, debe llamarla con 2 argumentos, ni más ni menos:
#
# # Ejemplo
# Esta función espera 2 argumentos y obtiene 2 argumentos:
# ```
# my_function <- function(fname, lname) {
#   paste(fname, lname)
# }
#
# my_function("Peter", "Griffin")
# Si intenta llamar a la función con 1 o 3 argumentos, obtendrá un error:
#
# Ejemplo
# Esta función espera 2 argumentos y obtiene 1 argumento:
#
# my_function <- function(fname, lname) {
#   paste(fname, lname)
# }
#
# my_function("Peter")
# ```
# # Valor del parámetro predeterminado
# El siguiente ejemplo muestra cómo utilizar un valor de parámetro predeterminado.
#
# Si llamamos a la función sin un argumento, utiliza el valor predeterminado:
#
# # Ejemplo
# ```
# my_function <- function(country = "Norway") {
#   paste("I am from", country)
# }
#
# my_function("Sweden")
# my_function("India")
# my_function() # will get the default value, which is Norway
# my_function("USA")
# ```
# # Valores de retorno
# Para que una función devuelva un resultado, utilice la ```return()```función:
#
# # Ejemplo
# ```
# my_function <- function(x) {
#   return (5 * x)
# }
#
# print(my_function(3))
# print(my_function(5))
# print(my_function(9))
# ```
# La salida del código anterior será:
# ```
# [1] 15
# [1] 25
# [1] 45
# ```

# %% [markdown]
# # Funciones anidadas
# Hay dos formas de crear una función anidada:
#
# Llamar a una función dentro de otra función.
# Escribe una función dentro de una función.
# Ejemplo
# Llamar a una función dentro de otra función:
# ```
# Nested_function <- function(x, y) {
#   a <- x + y
#   return(a)
# }
#
# Nested_function(Nested_function(2,2), Nested_function(3,3))
# ```
# Ejemplo explicado
# La función le dice a x que sume y.
#
# La primera entrada ```Nested_function(2,2)``` es "x" de la función principal.
#
# La segunda entrada ```Nested_function(3,3)``` es "y" de la función principal.
#
# Por lo tanto, la salida es (2+2) + (3+3) = 10 .
#
# # Ejemplo
# Escribe una función dentro de una función:
# ```
# Outer_func <- function(x) {
#   Inner_func <- function(y) {
#     a <- x + y
#     return(a)
#   }
#   return (Inner_func)
# }
# output <- Outer_func(3) # To call the Outer_func
# output(5)
# ```
# # Ejemplo explicado
# No puedes llamar directamente a la función porque Inner_func se ha definido (anidado) dentro de Outer_func.
#
# Necesitamos llamar a Outer_func primero para poder llamar a Inner_func como segundo paso.
#
# Necesitamos crear una nueva variable llamada salida y darle un valor, que aquí es 3.
#
# Luego imprimimos la salida con el valor deseado de "y", que en este caso es 5.
#
# Por tanto el resultado es 8 (3 + 5).

# %% [markdown]
# # Recursión
# R también acepta la recursión de funciones, lo que significa que una función definida puede llamarse a sí misma.
#
# La recursión es un concepto matemático y de programación común. Significa que una función se llama a sí misma. Esto tiene la ventaja de que permite recorrer los datos en bucle para llegar a un resultado.
#
# El desarrollador debe tener mucho cuidado con la recursión, ya que puede resultar muy fácil escribir una función que nunca finalice o que utilice cantidades excesivas de memoria o potencia del procesador. Sin embargo, cuando se escribe correctamente, la recursión puede ser un método de programación muy eficiente y matemáticamente elegante.
#
# En este ejemplo, ```tri_recursion()``` se trata de una función que hemos definido para que se llame a sí misma ("recurse"). Utilizamos la kvariable como dato, que decrementa ( -1) cada vez que realizamos la recursión. La recursión finaliza cuando la condición no es mayor que 0 (es decir, cuando es 0).
#
# Para un desarrollador nuevo puede llevar algún tiempo comprender exactamente cómo funciona esto; la mejor forma de descubrirlo es probándolo y modificándolo.
#
# # Ejemplo
# ```
# tri_recursion <- function(k) {
#   if (k > 0) {
#     result <- k + tri_recursion(k - 1)
#     print(result)
#   } else {
#     result = 0
#     return(result)
#   }
# }
# tri_recursion(6)
# ```

# %% [markdown]
# # Variables globales
# Las variables que se crean fuera de una función se conocen como variables globales .
#
# Las variables globales pueden ser utilizadas por todos, tanto dentro como fuera de las funciones.
#
# # Ejemplo
# Crea una variable fuera de una función y úsala dentro de la función:
# ```
# txt <- "awesome"
# my_function <- function() {
#   paste("R is", txt)
# }
#
# my_function()
# ```
# Si creas una variable con el mismo nombre dentro de una función, esta variable será local y solo podrá usarse dentro de la función. La variable global con el mismo nombre permanecerá como estaba, global y con el valor original.
#
# # Ejemplo
# Crea una variable dentro de una función con el mismo nombre que la variable global:
# ```
# txt <- "global variable"
# my_function <- function() {
#   txt = "fantastic"
#   paste("R is", txt)
# }
#
# my_function()
#
# txt # print txt
# ```
# Si intenta imprimir txt, devolverá " variable global " porque estamos imprimiendo txtfuera de la función.
#
#
# El operador de asignación global
# Normalmente, cuando se crea una variable dentro de una función, esa variable es local y solo se puede utilizar dentro de esa función.
#
# Para crear una variable global dentro de una función, puede utilizar el operador de asignación global<<-
#
# # Ejemplo
# Si utiliza el operador de asignación ```<<-```, la variable pertenece al ámbito global:
# ```
# my_function <- function() {
# txt <<- "fantastic"
#   paste("R is", txt)
# }
#
# my_function()
#
# print(txt)
# ```
#
# Además, utilice el operador de asignación global si desea cambiar una variable global dentro de una función:
#
# # Ejemplo
# Para cambiar el valor de una variable global dentro de una función, haga referencia a la variable utilizando el operador de asignación global <<-:
# ```
# txt <- "awesome"
# my_function <- function() {
#   txt <<- "fantastic"
#   paste("R is", txt)
# }
#
# my_function()
#
# paste("R is", txt)
# ```

# %% [markdown]
# # Vectores
# Un vector es simplemente una lista de elementos que son del mismo tipo.
#
# Para combinar la lista de elementos en un vector, utilice la c()función y separe los elementos con una coma.
#
# En el siguiente ejemplo, creamos una variable vectorial llamada frutas , que combina cadenas:
#
# # Ejemplo
# ```
# # Vector of strings
# fruits <- c("banana", "apple", "orange")
#
# # Print fruits
# fruits
# En este ejemplo, creamos un vector que combina valores numéricos:
#
# Ejemplo
# # Vector of numerical values
# numbers <- c(1, 2, 3)
#
# # Print numbers
# numbers
# ```
# Para crear un vector con valores numéricos en una secuencia, utilice el ```:``` operador:
#
# # Ejemplo
# ```
# # Vector with numerical values in a sequence
# numbers <- 1:10
#
# numbers
# También puedes crear valores numéricos con decimales en una secuencia, pero ten en cuenta que si el último elemento no pertenece a la secuencia, no se utiliza:
#
# # Ejemplo
# # Vector with numerical decimals in a sequence
# numbers1 <- 1.5:6.5
# numbers1
#
# # Vector with numerical decimals in a sequence where the last element is not used
# numbers2 <- 1.5:6.3
# numbers2
# ```
# # Resultado:
# ```
# [1] 1.5 2.5 3.5 4.5 5.5 6.5
# [1] 1.5 2.5 3.5 4.5 5.5
# ```
#
# En el siguiente ejemplo, creamos un vector de valores lógicos:
#
# # Ejemplo
# ```
# # Vector of logical values
# log_values <- c(TRUE, FALSE, TRUE, FALSE)
#
# log_values
# ```

# %% [markdown]
# # Longitud del vector
# Para saber cuántos elementos tiene un vector, utilice la ```length() ``` función:
#
# # Ejemplo
# ```
# fruits <- c("banana", "apple", "orange")
#
# length(fruits)
# ```

# %% [markdown]
# # Matrices
# Una matriz es un conjunto de datos bidimensional con columnas y filas.
#
# Una columna es una representación vertical de datos, mientras que una fila es una representación horizontal de datos.
#
# Se puede crear una matriz con la ```matrix()``` función. Especifique los parámetros nrowy ncolpara obtener la cantidad de filas y columnas:
#
# # Ejemplo
# ```
# # Create a matrix
# thismatrix <- matrix(c(1,2,3,4,5,6), nrow = 3, ncol = 2)
#
# # Print the matrix
# thismatrix
# ```

# %% [markdown]
# # Elementos de la matriz de acceso
# Puede acceder a los elementos mediante ```[ ]``` corchetes. El primer número "1" en el corchete especifica la posición de la fila, mientras que el segundo número "2" especifica la posición de la columna:
#
# # Ejemplo
# ```
# thismatrix <- matrix(c("apple", "banana", "cherry", "orange"), nrow = 2, ncol = 2)
#
# thismatrix[1, 2]
# Se puede acceder a toda la fila si especifica una coma después del número entre paréntesis:
# ```
# # Ejemplo
# ```
# thismatrix <- matrix(c("apple", "banana", "cherry", "orange"), nrow = 2, ncol = 2)
#
# thismatrix[2,]
# ```

# %% [markdown]
# Se puede acceder a toda la columna si especifica una coma antes del número entre corchetes:
#
# # Ejemplo
# ```
# thismatrix <- matrix(c("apple", "banana", "cherry", "orange"), nrow = 2, ncol = 2)
#
# thismatrix[,2]
# ```

# %% [markdown]
# # Marcos de datos
# Los marcos de datos son datos que se muestran en formato de tabla.
#
# Los marcos de datos pueden tener distintos tipos de datos en su interior. Mientras que la primera columna puede ser character, la segunda y la tercera pueden ser numerico logical. Sin embargo, cada columna debe tener el mismo tipo de datos.
#
# Utilice la ```data.frame()``` función para crear un marco de datos:
#
# # Ejemplo
# ```
# # Create a data frame
# Data_Frame <- data.frame (
#   Training = c("Strength", "Stamina", "Other"),
#   Pulse = c(100, 150, 120),
#   Duration = c(60, 30, 45)
# )
#
# # Print the data frame
# Data_Frame
# Resumir los datos
# Utilice la summary()función para resumir los datos de un marco de datos:
#
# Ejemplo
# Data_Frame <- data.frame (
#   Training = c("Strength", "Stamina", "Other"),
#   Pulse = c(100, 150, 120),
#   Duration = c(60, 30, 45)
# )
#
# Data_Frame
#
# summary(Data_Frame)
# ```
# Aprenderá más sobre la ```summary()``` función en la parte estadística del tutorial de R.
#
# # Acceder a elementos
# Podemos utilizar corchetes simples [ ], corchetes dobles [[ ]]o $ para acceder a las columnas de un marco de datos:
#
# # Ejemplo
# ```
# Data_Frame <- data.frame (
#   Training = c("Strength", "Stamina", "Other"),
#   Pulse = c(100, 150, 120),
#   Duration = c(60, 30, 45)
# )
#
# Data_Frame[1]
#
# Data_Frame[["Training"]]
#
# Data_Frame$Training
# ```
#
# # Agregar filas
# Utilice la ```rbind()``` función para agregar nuevas filas en un marco de datos:
#
# # Ejemplo
# ```
# Data_Frame <- data.frame (
#   Training = c("Strength", "Stamina", "Other"),
#   Pulse = c(100, 150, 120),
#   Duration = c(60, 30, 45)
# )
# ```
# ```
# # Add a new row
# New_row_DF <- rbind(Data_Frame, c("Strength", 110, 110))
# ```
# ```
# # Print the new row
# New_row_DF
# ```
# # Agregar columnas
# Utilice la cbind()función para agregar nuevas columnas en un marco de datos:
#
# # Ejemplo
# ```
# Data_Frame <- data.frame (
#   Training = c("Strength", "Stamina", "Other"),
#   Pulse = c(100, 150, 120),
#   Duration = c(60, 30, 45)
# )
#
# # Add a new column
# New_col_DF <- cbind(Data_Frame, Steps = c(1000, 6000, 2000))
#
# # Print the new column
# New_col_DF
# ```

# %% [markdown]
# # Factores
# Los factores se utilizan para categorizar datos. Algunos ejemplos de factores son:
#
# Demografía: masculino/femenino
# Música: Rock, Pop, Clásica, Jazz
# Entrenamiento: Fuerza, Resistencia
# Para crear un factor, utilice la factor()función y agregue un vector como argumento:
#
# # Ejemplo
# ```
# # Create a factor
# music_genre <- factor(c("Jazz", "Rock", "Classic", "Classic", "Pop", "Jazz", "Rock", "Jazz"))
#
# # Print the factor
# music_genre
# Resultado:
#
# [1] Jazz Rock Clásico Clásico Pop Jazz Rock Jazz
# Niveles: Jazz clásico Pop Rock
# ```
# En el ejemplo anterior se puede ver que el factor tiene cuatro niveles (categorías): Clásico, Jazz, Pop y Rock.
#
# Para imprimir solo los niveles, utilice la levels()función:
#
# # Ejemplo
# ```
# music_genre <- factor(c("Jazz", "Rock", "Classic", "Classic", "Pop", "Jazz", "Rock", "Jazz"))
#
# levels(music_genre)
# Resultado:
#
# [1] "Clásico" "Jazz" "Pop" "Rock"
# ```
# También puedes establecer los niveles agregando el levelsargumento dentro de la ```factor()``` función:
#
# # Ejemplo
# ```
# music_genre <- factor(c("Jazz", "Rock", "Classic", "Classic", "Pop", "Jazz", "Rock", "Jazz"), levels = c("Classic", "Jazz", "Pop", "Rock", "Other"))
#
# levels(music_genre)
# ```
# # Resultado:
# ```
# [1] "Clásico" "Jazz" "Pop" "Rock" "Otros"
# Longitud del factor
# Utilice la length()función para averiguar cuántos elementos hay en el factor:
#
# Ejemplo
# music_genre <- factor(c("Jazz", "Rock", "Classic", "Classic", "Pop", "Jazz", "Rock", "Jazz"))
#
# length(music_genre)
# Resultado:
#
# [1] 8
# Factores de acceso
# Para acceder a los elementos de un factor, consulte el número de índice, utilizando []corchetes:
#
# Ejemplo
# Acceda al tercer elemento:
# ```
# music_genre <- factor(c("Jazz", "Rock", "Classic", "Classic", "Pop", "Jazz", "Rock", "Jazz"))
#
# music_genre[3]
# Resultado:
# ```
# [1] Clásico
# Niveles: Jazz clásico Pop Rock
# Cambiar el valor del artículo
# ```
# Para cambiar el valor de un elemento específico, consulte el número de índice:
#
# # Ejemplo
# Cambiar el valor del tercer elemento:
# ```
# music_genre <- factor(c("Jazz", "Rock", "Classic", "Classic", "Pop", "Jazz", "Rock", "Jazz"))
#
# music_genre[3] <- "Pop"
#
# music_genre[3]
# ```
# # Resultado:
# ```
# [1] Estallido
# Niveles: Jazz clásico Pop Rock
# ```

# %% [markdown]
# # Trazado R
# # Plot
# La ```plot()``` función se utiliza para dibujar puntos (marcadores) en un diagrama.
#
# La función toma parámetros para especificar puntos en el diagrama.
#
# El parámetro 1 especifica puntos en el eje x .
#
# El parámetro 2 especifica puntos en el eje y .
#
# En su forma más simple, puedes usar la plot()función para representar gráficamente dos números uno contra el otro:
#
# # Ejemplo
# Dibuje un punto en el diagrama, en la posición (1) y la posición (3):
# ```
# plot(1, 3)
# ```

# %% [markdown]
# ![r_plot_simple.png](data:image/png;base64,...)

# %% [markdown]
# Para dibujar más puntos, utilice vectores :
#
# # Ejemplo
# Dibuje dos puntos en el diagrama, uno en la posición (1, 3) y otro en la posición (8, 10):
# ```
# plot(c(1, 8), c(3, 10))
# ```

# %% [markdown]
# ![r_plot1.png](data:image/png;base64,...)

# %% [markdown]
# # Puntos múltiples
# Puedes trazar tantos puntos como desees, sólo asegúrate de tener la misma cantidad de puntos en ambos ejes:
#
# # Ejemplo
# ```
# plot(c(1, 2, 3, 4, 5), c(3, 7, 8, 9, 12))
# ```

# %% [markdown]
# ![r_plot2.png](data:image/png;base64,...)

# %% [markdown]
# Para una mejor organización, cuando tienes muchos valores, es mejor utilizar variables:
#
# # Ejemplo
# ```
# x <- c(1, 2, 3, 4, 5)
# y <- c(3, 7, 8, 9, 12)
# ```
# plot(x, y)
# # Resultado:

# %% [markdown]
# ![r_plot2 (1).png](data:image/png;base64,...)

# %% [markdown]
# # Secuencias de puntos
# Si desea dibujar puntos en una secuencia, tanto en el eje x como en el eje y , utilice el ```:``` operador:
#
# # Ejemplo
# ```
# plot(1:10)
# ```

# %% [markdown]
# ![plot.png](data:image/png;base64,...)

# %% [markdown]
# # Dibujar una línea
# La plot() función también toma un typeparámetro con el valor lpara dibujar una línea para conectar todos los puntos del diagrama:
#
# # Ejemplo
# ```
# plot(1:10, type="l")
# ```

# %% [markdown]
# ![r_plot_line.png](data:image/png;base64,...)

# %% [markdown]
# # Etiquetas de la trama
# La plot() función también acepta otros parámetros, como main, xlaby ylab si desea personalizar el gráfico con un título principal y diferentes etiquetas para los ejes x e y:
#
# # Ejemplo
# ```
# plot(1:10, main="My Graph", xlab="The x-axis", ylab="The y axis")
# ```
# Resultado:

# %% [markdown]
# ![r_plot_labels.png](data:image/png;base64,...)

# %% [markdown]
# # Aspecto del gráfico
# Hay muchos otros parámetros que puedes utilizar para cambiar la apariencia de los puntos.
#
# # Colores
# Utilice para agregar un color a los puntos: ```col="color"```
#
# # Ejemplo
# ```
# plot(1:10, col="red")
# ```
# Resultado:

# %% [markdown]
# ![r_plot_col.png](data:image/png;base64,...)

# %% [markdown]
# # Tamaño
# Úselo para cambiar el tamaño de los puntos ( es el predeterminado, mientras que significa 50% más pequeño y significa 100% más grande):```cex=number10.52```
#
# # Ejemplo
# ```
# plot(1:10, cex=2)
# ```
# # Resultado:

# %% [markdown]
# ![r_plot_cex.png](data:image/png;base64,...)

# %% [markdown]
# # Gráficos de líneas
# Un gráfico lineal tiene una línea que conecta todos los puntos de un diagrama.
#
# Para crear una línea, utilice la plot()función y agregue el typeparámetro con un valor de "l":
#
# # Ejemplo
# ```
# plot(1:10, type="l")
# ```
# # Resultado:

# %% [markdown]
# ![r_plot_line (1).png](data:image/png;base64,...)

# %% [markdown]
# # **Color de línea**
# El color de la línea es negro por defecto. Para cambiar el color, utilice el colparámetro:
#
# # Ejemplo
# ```
# plot(1:10, type="l", col="blue")
# ```
# # Resultado:

# %% [markdown]
# ![r_plot_l_color.png](data:image/png;base64,...)

# %% [markdown]
# # Ancho de línea
# Para cambiar el ancho de la línea, use el lwd parámetro ( 1es el predeterminado, mientras que 0.5significa 50% más pequeño y 2significa 100% más grande):
#
# # Ejemplo
# ```
# plot(1:10, type="l", lwd=2)
# ```

# %% [markdown]
# ![r_plot_l_width.png](data:image/png;base64,...)

# %% [markdown]
# # Estilos de línea
# La línea es continua de forma predeterminada. Utilice el ltyparámetro con un valor de 0 a 6 para especificar el formato de la línea.
#
# Por ejemplo, ```lty=3``` se mostrará una línea punteada en lugar de una línea continua:
#
# # Ejemplo
# ```
# plot(1:10, type="l", lwd=5, lty=3)
# ```
# Resultado:

# %% [markdown]
# ![r_plot_dotted.png](data:image/png;base64,...)

# %% [markdown]
# # Valores de parámetros disponibles para lty:
#
# 0 elimina la linea
#
# 1 muestra una línea sólida
#
# 2 muestra una línea discontinua
#
# 3 muestra una línea de puntos
#
# 4 muestra una línea de "puntos y guiones"
#
# 5 muestra una línea "discontinua larga"
#
# 6 muestra una línea de "dos puntos"
#
#
# # Líneas múltiples
# Para mostrar más de una línea en un gráfico, utilice la plot()función junto con la lines()función:
#
# # Ejemplo

# %% [markdown]
# ```
# line1 <- c(1,2,3,4,5,10)
# line2 <- c(2,5,7,8,9,10)
#
# plot(line1, type = "l", col = "blue")
# lines(line2, type="l", col = "red")
# Resultado:
# ```

# %% [markdown]
# ![r_plot_multi.png](data:image/png;base64,...)

# %% [markdown]
# # Diagramas de dispersión
# Aprendiste en el capítulo Trazado que la plot()función se usa para graficar números entre sí.
#
# Un "diagrama de dispersión" es un tipo de gráfico que se utiliza para mostrar la relación entre dos variables numéricas y traza un punto para cada observación.
#
# Necesita dos vectores de la misma longitud, uno para el eje x (horizontal) y otro para el eje y (vertical):
#
# # Ejemplo
# ```
# x <- c(5,7,8,7,2,2,9,4,11,12,9,6)
# y <- c(99,86,87,88,111,103,87,94,78,77,85,86)
#
# plot(x, y)
# ```
# # Resultado:

# %% [markdown]
# ![r_scatterplot.png](data:image/png;base64,...)

# %% [markdown]
# La observación en el ejemplo anterior debería mostrar el resultado de 12 autos pasando.
#
# Puede que esto no quede claro para alguien que vea el gráfico por primera vez, así que agreguemos un encabezado y etiquetas diferentes para describir mejor el diagrama de dispersión:
#
# # Ejemplo
# ```
# x <- c(5,7,8,7,2,2,9,4,11,12,9,6)
# y <- c(99,86,87,88,111,103,87,94,78,77,85,86)
#
# plot(x, y, main="Observation of Cars", xlab="Car age", ylab="Car speed")
# ```
# # Resultado:

# %% [markdown]
# ![r_scatterplot_car.png](data:image/png;base64,...)

# %% [markdown]
# # Comparar parcelas
# En el ejemplo anterior, parece haber una relación entre la velocidad del automóvil y su antigüedad, pero ¿qué sucede si graficamos también las observaciones de otro día? ¿El diagrama de dispersión nos dirá algo más?
#
# Para comparar la gráfica con otra gráfica, utilice la points()función:
#
# # Ejemplo
# Dibuje dos gráficos en la misma figura:
# ```
# # day one, the age and speed of 12 cars:
# x1 <- c(5,7,8,7,2,2,9,4,11,12,9,6)
# y1 <- c(99,86,87,88,111,103,87,94,78,77,85,86)
#
# # day two, the age and speed of 15 cars:
# x2 <- c(2,2,8,1,15,8,12,9,7,3,11,4,7,14,12)
# y2 <- c(100,105,84,105,90,99,90,95,94,100,79,112,91,80,85)
#
# plot(x1, y1, main="Observation of Cars", xlab="Car age", ylab="Car speed", col="red", cex=2)
# points(x2, y2, col="blue", cex=2)
# ```
# # Resultado:

# %% [markdown]
# ![r_scatterplot_car2.png](data:image/png;base64,...)

# %% [markdown]
# # Gráficos circulares
# Un gráfico circular es una vista gráfica circular de datos.
#
# Utilice la pie() función para dibujar gráficos circulares:
#
# # Ejemplo
# # Create a vector of pies
# ```
# x <- c(10,20,30,40)
#
# # Display the pie chart
# pie(x)
# ```
# Resultado:

# %% [markdown]
# ![r_pie.png](data:image/png;base64,...)

# %% [markdown]
# # Ángulo de inicio
# Puede cambiar el ángulo inicial del gráfico circular con el init.angleparámetro.
#
# El valor de init.anglese define con el ángulo en grados, donde el ángulo predeterminado es 0.
#
# # Ejemplo
# Comience la primera tarta a 90 grados:
#
# # Create a vector of pies
# ```
# x <- c(10,20,30,40)
#
# # Display the pie chart and start the first pie at 90 degrees
# pie(x, init.angle = 90)
# ```
# # Resultado:

# %% [markdown]
# ![r_pie_angle.png](data:image/png;base64,...)

# %% [markdown]
# # Etiquetas y encabezado
# Utilice el ```label```parámetro para agregar una etiqueta al gráfico circular y utilice el main parámetro para agregar un encabezado:
#
# # Ejemplo
# ```
# # Create a vector of pies
# x <- c(10,20,30,40)
#
# # Create a vector of labels
# mylabel <- c("Apples", "Bananas", "Cherries", "Dates")
#
# # Display the pie chart with labels
# pie(x, label = mylabel, main = "Fruits")
# ```
# # Resultado:

# %% [markdown]
# ![r_pie_label.png](data:image/png;base64,...)

# %% [markdown]
# # Bandera
# Puedes agregar un color a cada gráfico circular con el colparámetro:
#
# # Ejemplo
# ```
# # Create a vector of colors
# colors <- c("blue", "yellow", "green", "black")
#
# # Display the pie chart with colors
# pie(x, label = mylabel, main = "Fruits", col = colors)
# ```
# # Resultado:

# %% [markdown]
# ![r_pie_col.png](data:image/png;base64,...)

# %% [markdown]
# # Leyenda
# Para agregar una lista de explicaciones para cada gráfico circular, utilice la legend()función:
#
# # Ejemplo
# ```
# # Create a vector of labels
# mylabel <- c("Apples", "Bananas", "Cherries", "Dates")
#
# # Create a vector of colors
# colors <- c("blue", "yellow", "green", "black")
#
# # Display the pie chart with colors
# pie(x, label = mylabel, main = "Pie Chart", col = colors)
#
# # Display the explanation box
# legend("bottomright", mylabel, fill = colors)
# ```
# # Resultado:

# %% [markdown]
# ![r_pie_legend.png](data:image/png;base64,...)

# %% [markdown]
# # Gráficos de barras
# Un gráfico de barras utiliza barras rectangulares para visualizar datos. Los gráficos de barras se pueden mostrar de forma horizontal o vertical. La altura o longitud de las barras son proporcionales a los valores que representan.
#
# Utilice la ```barplot()``` función para dibujar un gráfico de barras verticales:
#
# # Ejemplo
# ```
# # x-axis values
# x <- c("A", "B", "C", "D")
#
# # y-axis values
# y <- c(2, 4, 6, 8)
#
# barplot(y, names.arg = x)
# ```
# # Resultado:

# %% [markdown]
# ![r_bar.png](data:image/png;base64,...)

# %% [markdown]
# # Ejemplo explicado
# La x variable representa valores en el eje x (A,B,C,D)
# La y variable representa valores en el eje y (2,4,6,8)
# Luego usamos la barplot()función para crear un gráfico de barras de los valores.
# names.argdefine los nombres de cada observación en el eje x
# # Color de la barra
# Utilice el col parámetro para cambiar el color de las barras:
#
# # Ejemplo
# ```
# x <- c("A", "B", "C", "D")
# y <- c(2, 4, 6, 8)
#
# barplot(y, names.arg = x, col = "red")
# ```
# # Resultado:

# %% [markdown]
# ![r_bar_col.png](data:image/png;base64,...))

# %% [markdown]
# # Ancho de barra
# Utilice el ```width``` parámetro para cambiar el ancho de las barras:
#
# # Ejemplo
# ```
# x <- c("A", "B", "C", "D")
# y <- c(2, 4, 6, 8)
#
# barplot(y, names.arg = x, width = c(1,2,3,4))
# ```
# # Resultado:

# %% [markdown]
# ![r_bar_width.png](data:image/png;base64,...)

# %% [markdown]
# # Conjunto de datos
# Un conjunto de datos es una colección de datos, a menudo presentados en una tabla.
#
# Hay un conjunto de datos integrado popular en R llamado " mtcars " (Motor Trend Car Road Tests), que se recuperó de la revista Motor Trend estadounidense de 1974.
#
# En los ejemplos siguientes (y en los próximos capítulos), utilizaremos el mtcars conjunto de datos para fines estadísticos:
#
# # Ejemplo
# ```
# # Print the mtcars data set
# ```
# mtcars
# # Resultado:
# ```
#
#                      mpg cil disp hp drat wt qsec vs am gear carb
# Mazda RX4 21.0 6 160.0 110 3.90 2.620 16.46 0 1 4 4
# Mazda RX4 Wag 21.0 6 160.0 110 3.90 2.875 17.02 0 1 4 4
# Datsun 710 22,8 4 108,0 93 3,85 2,320 18,61 1 1 4 1
# Avispón 4 Conducir 21,4 6 258,0 110 3,08 3,215 19,44 1 0 3 1
# Hornet Sportaproximadamente 18,7 8 360,0 175 3,15 3,440 17,02 0 0 3 2
# Valiente 18,1 6 225,0 105 2,76 3,460 20,22 1 0 3 1
# Plumero 360 14,3 8 360,0 245 3,21 3,570 15,84 0 0 3 4
# Mercedes 240D 24,4 4 146,7 62 3,69 3,190 20,00 1 0 4 2
# Mercurio 230 22,8 4 140,8 95 3,92 3,150 22,90 1 0 4 2
# Mercedes 280 19,2 6 167,6 123 3,92 3,440 18,30 1 0 4 4
# Mercedes 280C 17,8 6 167,6 123 3,92 3,440 18,90 1 0 4 4
# Mercedes 450SE 16,4 8 275,8 180 3,07 4,070 17,40 0 0 3 3
# Mercedes 450SL 17,3 8 275,8 180 3,07 3,730 17,60 0 0 3 3
# Mercedes 450SLC 15,2 8 275,8 180 3,07 3,780 18,00 0 0 3 3
# Cadillac Fleetwood 10,4 8 472,0 205 2,93 5,250 17,98 0 0 3 4
# Lincoln Continental 10,4 8 460,0 215 3,00 5,424 17,82 0 0 3 4
# Chrysler Imperial 14,7 8 440,0 230 3,23 5,345 17,42 0 0 3 4
# Fiat 128 32,4 4 78,7 66 4,08 2,200 19,47 1 1 4 1
# Honda Civic 30,4 4 75,7 52 4,93 1,615 18,52 1 1 4 2
# Toyota Corolla 33,9 4 71,1 65 4,22 1,835 19,90 1 1 4 1
# Toyota Corona 21.5 4 120.1 97 3.70 2.465 20.01 1 0 3 1
# Dodge Challenger 15.5 8 318.0 150 2.76 3.520 16.87 0 0 3 2
# Jabalina AMC 15,2 8 304,0 150 3,15 3,435 17,30 0 0 3 2
# Camaro Z28 13,3 8 350,0 245 3,73 3,840 15,41 0 0 3 4
# Pontiac Firebird 19,2 8 400,0 175 3,08 3,845 17,05 0 0 3 2
# Fiat X1-9 27,3 4 79,0 66 4,08 1,935 18,90 1 1 4 1
# Porsche 914-2 26,0 4 120,3 91 4,43 2,140 16,70 0 1 5 2
# Loto Europa 30,4 4 95,1 113 3,77 1,513 16,90 1 1 5 2
# Ford Pantera L 15.8 8 351.0 264 4.22 3.170 14.50 0 1 5 4
# Ferrari Dino 19,7 6 145,0 175 3,62 2,770 15,50 0 1 5 6
# Maserati Bora 15,0 8 301,0 335 3,54 3,570 14,60 0 1 5 8
# Volvo 142E 21,4 4 121,0 109 4,11 2,780 18,60 1 1 4 2
# ```
# # Información sobre el conjunto de datos
# Puede utilizar el signo de interrogación ( ? ) para obtener información sobre el mtcarsconjunto de datos:
#
# # Ejemplo
# ```
# # Use the question mark to get information about the data set
#
# ?mtcars
# # Resultado:
#
#
# mtcars {conjuntos de datos}	Documentación R
# Pruebas de carretera de coches de Motor Trend
# Descripción
# Los datos se extrajeron de la revista estadounidense Motor Trend de 1974 y comprenden el consumo de combustible y 10 aspectos del diseño y el rendimiento de 32 automóviles (modelos 1973-74).
#
# Uso
# coches mt
# Formato
# Un marco de datos con 32 observaciones sobre 11 variables (numéricas).
#
# [, 1]	millas por galón	Millas/galón (EE. UU.)
# [, 2]	cilindro	Número de cilindros
# [, 3]	Desplegar	Desplazamiento (pulgadas cúbicas)
# [, 4]	caballos de fuerza	Caballos de fuerza brutos
# [, 5]	Maldita sea	Relación del eje trasero
# [, 6]	peso	Peso (1000 libras)
# [, 7]	qsec	Tiempo de 1/4 de milla
# [, 8]	contra	Motor (0 = en forma de V, 1 = recto)
# [, 9]	soy	Transmisión (0 = automática, 1 = manual)
# [,10]	engranaje	Número de marchas hacia adelante
# [,11]	carburador	Número de carburadores
# Nota
# Henderson y Velleman (1981) comentan en una nota al pie de la Tabla 1: 'La codificación no crucial de Hocking [transcriptor original] del motor rotativo del Mazda como un motor de seis cilindros en línea y del motor plano del Porsche como un motor en V, así como la inclusión del Mercedes 240D diésel, se han conservado para permitir realizar comparaciones directas con análisis anteriores.'
#
# Fuente
# Henderson y Velleman (1981), Construcción interactiva de modelos de regresión múltiple. Biometrics , 37 , 391-411.
#
#
# Ejemplos
# requerir(gráficos)
# pares(mtcars, main = "datos de mtcars", gap = 1/4)
# coplot(mpg ~ disp | as.factor(cil), datos = mtcars,
#        panel = panel.suave, filas = 1)
# ## posiblemente más significativo, por ejemplo, para gráficos de resumen() o bivariados:
# mtcars2 <- dentro de (mtcars, {
#    vs <- factor(vs, etiquetas = c("V", "S"))
#    am <- factor(am, etiquetas = c("automático", "manual"))
#    cil <- ordenado(cil)
#    engranaje <- ordenado(engranaje)
#    carb <- ordenado(carb)
# })
# resumen(mtcars2)
# ```

# %% [markdown]
# # Ejercicio 1: Análisis exploratorio de datos de iris
#
# # Cargar los datos de iris
# ```
# data(iris)
#
# # Ver las primeras filas
# head(iris)
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">1</sup>
#
# # Resumen de las estadísticas
# summary(iris)
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">1</sup>
#
# # Gráfico de dispersión de longitud vs ancho de sépalo
# plot(iris$Sepal.Length, iris$Sepal.Width,
#      main = "Longitud vs Ancho de Sépalo de Iris",
#      xlab = "Longitud de Sépalo",
#      ylab = "Ancho de Sépalo",
#      pch = 19)
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">1</sup>
#
# # Gráfico de dispersión de longitud vs ancho de pétalo
# plot(iris$Petal.Length, iris$Petal.Width,
#      main = "Longitud vs Ancho de Pétalo de Iris",
#      xlab = "Longitud de Pétalo",
#      ylab = "Ancho de Pétalo",
#      pch = 19)
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">2</sup>
#
# # Gráfico de dispersión de longitud de sépalo y pétalo
# plot(iris$Sepal.Length, iris$Petal.Length,
#      col = iris$Species,
#      main = "Longitud de Sépalo vs Longitud de Pétalo",
#      xlab = "Longitud de Sépalo",
#      ylab = "Longitud de Pétalo",
#      pch = 19)
# legend("topleft",
#        unique(iris$Species),
#        fill = unique(iris$Species))
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:tra
# ```

# %% [markdown]
# # Ejercicio 2: Regresión lineal simple
# ```
# # Generar algunos datos de ejemplo
# x <- c(151, 174, 138, 186, 128, 136, 179, 163, 152, 131)
# y <- c(63, 81, 56, 91, 47, 57, 76, 72, 62, 48)
#
# # Gráfico de dispersión
# plot(y ~ x, main = "Diagrama de dispersión de Ejemplo")
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">3</sup>
#
# # Ajustar el modelo de regresión lineal
# modelo <- lm(y ~ x)
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">3</sup>
#
# # Ver el resumen del modelo
# summary(modelo)
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">4</sup>
#
# # Agregar la línea de regresión al gráfico de dispersión
# abline(modelo, col = "red")
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">4</sup>
#
# # Predecir y para x = 170
# predict(modelo, data.frame(x = 170))
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">4</sup>
#
# # Obtener intervalos de confianza del 95%
# predict(modelo, data.frame(x = 170), interval = "confidence")
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">5</sup>
#
# # Obtener límites de predicción del 95%
# predict(modelo, data.frame(x = 170), interval = "prediction")
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">5</sup>
#
# # Plotear residuos vs ajustados
# plot(modelo, which = 1)
# <sup className="inline select-none [&>a]:rounded-2xl [&>a]:border [&>a]:px-1.5 [&>a]:py-0.5 [&>a]:transition-colors shadow [&>a]:bg-ds-bg-subtle [&>a]:text-xs [&>svg]:w-4 [&>svg]:h-4 relative -top-[2px]">5</sup>
# ```
